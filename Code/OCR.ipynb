# %% [markdown]
# ![cv11.png](attachment:cv11.png)

# %% [markdown]
# ![cv1.png](attachment:cv1.png)

# %% [markdown]
# ![cv111.png](attachment:cv111.png)

# %% [markdown]
# ![1200px--Portable_scanner_and_OCR_%28video%29.webm-2.jpg](attachment:1200px--Portable_scanner_and_OCR_%28video%29.webm-2.jpg)

# %% [markdown]
# ## Task-
# *Implement an object detector which identifies the classes of the objects in
# an image or video*
#
# **OR**
#
# *Character detector which extracts printed or handwritten text from an
# image or video*

# %% [markdown]
# ## I have implemented optical character recognition(OCR)

# %%
pip install pytesseract

# %% [markdown]
# ### Importing libraries

# %%
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
from pytesseract import Output
import cv2

# %% [markdown]
# ### Reading the image

# %%
image = cv2.imread('OCR.jpg')
print("The type of this input is {}".format(type(image)))
print("Shape: {}".format(image.shape))
plt.imshow(image)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (729, 990, 3)

# %%
C:\Program Files\Tesseract-OCR

# %% [markdown]
# ### Greyscale-
# #### Because it is a one layer image from 0-255 whereas the RGB has three different layer image.
# #### So that is a reason we prefer grey scale image instead of RGB-less information needs to be provided for each pixel

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 989.5, 728.5, -0.5)

# %% [markdown]
# ### Extracting the text from picture

# %% [markdown]
# ##### pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\\tesseract.exe'
# print(pytesseract.image_to_string(image))

# %% [markdown]
# ![Picture4.png](attachment:Picture4.png)
